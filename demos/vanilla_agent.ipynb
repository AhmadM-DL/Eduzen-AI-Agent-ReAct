# %%
import sys
sys.path.append("..")

# %%
from agents.vanilla_agent import EduZenVanillaAgent
from utils.xlsx import get_student_leads, get_feedback_data, get_workshop_leads

# %%
agent = EduZenVanillaAgent()
message = "Hello! What services does EduZen offer?"
response, _ = agent.chat(message, [])

# %%
print(f" user: {message}")
print(f" assistant: {response}")
# Out:
#  user: Hello! What services does EduZen offer?
#  assistant: EduZen offers a variety of innovative educational services designed to foster learning and professional growth. Here are the key services we provide:
#
# 1. **Student-Teacher Matching (Grades 1-12):** We connect students from grade 1 to 12 with suitable teachers. The service is free for students, while teachers pay 20% of their first paycheck upon successful matching.
#
# 2. **University Student-Teacher Matching:** Similar to the above service, we match university students with appropriate teachers. The service is free for students, and teachers pay 20% of their first paycheck upon successful matching.
#
# 3. **Educational Program Advertisement:** We provide a platform for the advertisement of workshops, bootcamps, and educational programs. The revenue is generated through a 10% commission from program providers for each registered attendee.
#
# 4. **Language Teaching Services:** We offer language teaching services in English, Arabic, German, French, and Spanish. These services are available for all levels and age groups.
#
# 5. **International University Applications:** We assist in the application process for international universities. The pricing is based on a flat fee that is only payable upon acceptance.
#
# These services are provided with the utmost flexibility and a unique pay-when-you-succeed model. We prioritize creating a community-driven approach to education and strive to democratize access to quality education.

# %%
message = "I'm a Grade 10 student in Cairo. I need help with mathematics and physics in Arabic. My email is student@example.com and my name is Ahmed Hassan."
response, _ = agent.chat(message, [])
student_leads = get_student_leads()
if student_leads is not None and not student_leads.empty:
    print(f"Found {len(student_leads)} student leads:")
    print(student_leads.tail().to_string(index=False))
else:
    print("No student leads found yet.")
# Out:
# Found 4 student leads:
#         name               email language             subjects    grade location  contact_info           timestamp
# Ahmed Hassan student@example.com   Arabic Mathematics, Physics       10    Cairo           NaN 2025-11-03 12:49:59
# Ahmed Hassan student@example.com   Arabic mathematics, physics       10    Cairo           NaN 2025-11-03 12:54:18
# Ahmed Hassan student@example.com   Arabic Mathematics, Physics       10    Cairo           NaN 2025-11-03 13:25:06
# Ahmed Hassan student@example.com   Arabic mathematics, physics Grade 10    Cairo           NaN 2025-11-03 14:00:59

# %%
message = "When was Eduzen created?"
response, _ = agent.chat(message, [])
feedback = get_feedback_data()
if feedback is not None and not feedback.empty:
    print(f"Found {len(feedback)} feedbacks:")
    print(feedback.tail().to_string(index=False))
else:
    print("No feedback found yet.")
# Out:
# Found 2 feedbacks:
#            user_question category urgency        contact_info           timestamp
# When was Eduzen created?  general     low                 NaN 2025-11-03 12:54:35
# When was Eduzen created?  general     low student@example.com 2025-11-03 13:25:37

# %%
message = "I want to advertise my 'Spear Head Competition and Land a Job' for developers. I expect 30 attandee. It will be on Novamber 20th. My name is Ahmad Mustapha. My organization is Al Mustapha Institute. My email address is ahmad.m.mustapha@hotmail.com."
response, _ = agent.chat(message, [])
workshop_leads = get_workshop_leads()
if workshop_leads is not None and not workshop_leads.empty:
    print(f"Found {len(workshop_leads)} feedbacks:")
    print(workshop_leads.tail().to_string(index=False))
else:
    print("No worksop leads found yet.")
# Out:
# Found 2 feedbacks:
#     organization_name contact_person                        email  phone program_type                          program_name                  description target_audience duration      location  expected_participants           timestamp
# Al Mustapha Institute Ahmad Mustapha ahmad.m.mustapha@hotmail.com    NaN  competition Spear Head Competition and Land a Job A competition for developers      Developers    1 day        Online                     30 2025-11-03 12:55:25
# Al Mustapha Institute Ahmad Mustapha ahmad.m.mustapha@hotmail.com    NaN  Competition Spear Head Competition and Land a Job A competition for developers      Developers    1 day Not specified                     30 2025-11-03 13:26:42
