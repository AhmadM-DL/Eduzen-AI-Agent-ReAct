# %%
import sys
sys.path.append("..")

# %%
from agents.react_lg_agent import EduZenReActAgent

# %%
personality = "casual"
agent = EduZenReActAgent(personality)
question = "Hello! What services does EduZen offer?"
print("=" * 80)
print(f"Question: {question}\n")
print("=" * 80)
final_answer, reasoning_steps = agent.chat(question, thread_id=f"{personality}")
print(f"Response: {final_answer}")
# Out:
# ...
# Question: Hello! What services does EduZen offer?
#
# Response: EduZen offers a range of innovative educational services, all designed with flexibility, community involvement, and success in mind. Here they are:
#
# 1. **Student-Teacher Matching (Grades 1-12)**: This service connects students from grade 1 to 12 with suitable teachers. The matching is done through our WhatsApp group "telmiz w istez". This service is free for students, and teachers pay a 20% commission on their first paycheck upon a successful match.
#
# 2. **University Student-Teacher Matching**: Similar to the service above, but this one is for university students. The matching is done via our WhatsApp group "taleb w istez". Again, it's free for students, and teachers pay a 20% commission of their first paycheck upon a successful match.
#
# ...

# %%
personality = "formal"
agent = EduZenReActAgent(personality)
question = "Hello! What services does EduZen offer?"
print("=" * 80)
print(f"Question: {question}\n")
print("=" * 80)
final_answer, reasoning_steps = agent.chat(question, thread_id=f"{personality}")
print(f"Response: {final_answer}")
# Out:
# ...
# Question: Hello! What services does EduZen offer?
#
# ...
# Response: EduZen offers a range of community-driven educational services, all with a unique pay-when-you-succeed model. Here are our main services:
#
# 1. **Student-Teacher Matching (Grades 1-12)**: This service is primarily delivered via our WhatsApp group "telmiz w istez". The service is free for students and aims to match them with suitable teachers. The teachers pay 20% of their first paycheck upon successful matching.
#
# 2. **University Student-Teacher Matching**: Similar to the previous service, but it targets university students and is delivered through the WhatsApp group "taleb w istez". Again, the service is free for students, and teachers pay 20% of their first paycheck upon successful matching.
#
# ...

# %%
personality = "supportive"
agent = EduZenReActAgent(personality)
question = "Hello! What services does EduZen offer?"
print("=" * 80)
print(f"Question: {question}\n")
print("=" * 80)
final_answer, reasoning_steps = agent.chat(question, thread_id=f"{personality}")
print(f"Response: {final_answer}")
# Out:
# ...
# Question: Hello! What services does EduZen offer?
#
# ...
# Response: EduZen offers several innovative educational services designed to empower students and educators alike. Our offerings can broadly be categorized into the following:
#
# 1. **Student-Teacher Matching (Grades 1-12)**: We connect students from grades 1-12 with qualified teachers based on their learning needs. This service is free for students, with teachers only paying a fee upon a successful match.
#
# 2. **University Student-Teacher Matching**: Similar to the service above, we offer a platform for university students to find the right teachers. Again, this is free for students, with teachers paying a fee only upon a successful match.
#
# 3. **Educational Program Advertisement**: We provide a platform for advertising educational programs like workshops, bootcamps, etc. Program providers pay a commission for each registered attendee.
#
# ...

# %% [markdown]
# Casual adds a little bit of funny emojis without discarding consistance.
# For our application all personalities work but we decide to move with casual.
